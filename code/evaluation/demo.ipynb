# %%
from csv import DictReader

with open("out/quantum-circuit-qubo-3B_label_data.csv", newline='', encoding='utf-8') as f:
    reader = DictReader(f)
    for row in reader:
        print("generated_circuit preview:", row["generated_circuit"][:20])
        print("qasm_valid:", row["qasm_valid"])
# Out:
# generated_circuit preview: OPENQASM 3.0;
# includ
# qasm_valid: 1
# generated_circuit preview: OPENQASM 3.0;
# includ
# qasm_valid: 1
# generated_circuit preview: OPENQASM 3.0;
# includ
# qasm_valid: 1
# generated_circuit preview: OPENQASM 3.0;
# includ
# qasm_valid: -1
# generated_circuit preview: OPENQASM 3.0;
# includ
# qasm_valid: 1
# generated_circuit preview: OPENQASM 3.0;
# includ
# qasm_valid: -1
# generated_circuit preview: OPENQASM 3.0;
# includ
# qasm_valid: 1
# generated_circuit preview: OPENQASM 3.0;
# includ
# qasm_valid: 1
# generated_circuit preview: OPENQASM 3.0;
# includ
# qasm_valid: 1
# generated_circuit preview: OPENQASM 3.0;
# includ
# qasm_valid: 1
# generated_circuit preview: OPENQASM 3.0;
# includ
# qasm_valid: 1
# generated_circuit preview: OPENQASM 3.0;
# includ
# qasm_valid: 1
# generated_circuit preview: OPENQASM 3.0;
# includ
# qasm_valid: 1
# generated_circuit preview: OPENQASM 3.0;
# includ
# qasm_valid: -1
# generated_circuit preview: OPENQASM 3.0;
# ...
